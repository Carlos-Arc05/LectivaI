# %%
! pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
#Importando la libreria necesaria para la lectura de datos
import pandas as pd

# %%
#Leyendo los datos de la GEIH2025
df_cgsse = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/cgsse.CSV", encoding='latin', sep=';')

# %%
df_cgsse
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %%
#Punto 1, 1.1 población total
Población_Total = df_cgsse['FEX_C18'].sum()
print("Población total nacionalestimada:", Población_Total)
# Out:
# Población total nacionalestimada: 52045001.000009045

# %%
# Población en edad de trabajar (15 años o más)
poblacion_edad_trabajar = df_cgsse[df_cgsse['FEX_C18'] >= 15]['FEX_C18'].sum()
print("Población en edad de trabajar:", poblacion_edad_trabajar)
# Out:
# Población en edad de trabajar: 52044416.25330352

# %%
#Calculo PEA
PEA = df_FuerzaTrabajo[df_FuerzaTrabajo['FT']==1]['FEX_C18'].sum()
print("Población Económicamente Activa (PEA):", PEA)

#Calculo PEI
PEI = df_FuerzaTrabajo[df_FuerzaTrabajo['FFT']==1]['FEX_C18'].sum()
print("Población Económicamente Inactiva (PEI):", PEI)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 #Calculo PEA
# ----> 2 PEA = df_FuerzaTrabajo[df_FuerzaTrabajo['FT']==1]['FEX_C18'].sum()
#       3 print("Población Económicamente Activa (PEA):", PEA)
#       5 #Calculo PEI
#
# NameError: name 'df_FuerzaTrabajo' is not defined
